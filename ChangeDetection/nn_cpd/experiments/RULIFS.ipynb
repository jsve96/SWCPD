# %%
import wrappers
import test_utils

from test_utils import Tester, run_test_on_dataset


dir_path = "../data/HASC/"


models = [wrappers.OrigRuLSIF(alpha=0.1, kernel_num=10, window_size=200, step=10, periods=1, height=0.1)]


for amodel in models:
    report = run_test_on_dataset(dir_path, amodel, downsample=1, margin=100, verbose=0, sigma=1.0,seed=12345)
    print(amodel)
    for rep in report:
        display(rep)
# Out:
# ../data/HASC/HASC_TS_10.csv
# [1275 2746 4184]
# [1275, 2746, 4184, 5597]
# [1264, 1663, 1804, 2243, 2344, 2743, 3684, 4184, 4593, 4734, 4894, 5083, 5283, 5597]
# ../data/HASC/HASC_TS_100.csv
# []
# [954]
# [353, 954]
# ../data/HASC/HASC_TS_11.csv
# [1513 1935]
# [1513, 1935, 3423]
# [1534, 1843, 2684, 3104, 3423]
# ../data/HASC/HASC_TS_14.csv
# [1429 2844 4098]
# [1429, 2844, 4098, 5952]
# [1414, 2843, 4083, 5952]
# ../data/HASC/HASC_TS_141.csv
# []
# [6200]
# [214, 463, 694, 874, 1224, 1873, 2193, 2584, 3504, 3943, 6200]
# ../data/HASC/HASC_TS_182.csv
# [4175 5290 6760 7750]
# [4175, 5290, 6760, 7750, 8740]
# [234, 624, 883, 1013, 4154, 4303, 4453, 5294, 5504, 6283, 6833, 7043, 7753, 8740]
# ../data/HASC/HASC_TS_185.csv
# [1525 3070 4320 5690 6930]
# [1525, 3070, 4320, 5690, 6930, 8260]
# [843, 1513, 3073, 4344, 5683, 6923, 8260]
# ../data/HASC/HASC_TS_19.csv
# [1473 2820]
# [1473, 2820, 4296]
# [1493, 2833, 3234, 4296]
# ../data/HASC/HASC_TS_20.csv
# [1575 3125]
# [1575, 3125, 4504]
# [374, 1564, 2084, 3113, 4504]
# ../data/HASC/HASC_TS_210.csv
# [1290]
# [1290, 2860]
# [1283, 2860]
# ../data/HASC/HASC_TS_225.csv
# [1291 2884 4272 5977]
# [1291, 2884, 4272, 5977, 7238]
# [224, 583, 723, 903, 1054, 1273, 1593, 1754, 1963, 2873, 4253, 5974, 6494, 7238]
# ../data/HASC/HASC_TS_23.csv
# [1443 1857]
# [1443, 1857, 2781]
# [214, 1434, 1864, 2781]
# ../data/HASC/HASC_TS_243.csv
# [1611 2979]
# [1611, 2979, 4111]
# [1613, 2964, 4111]
# ../data/HASC/HASC_TS_245.csv
# []
# [1303]
# [324, 474, 754, 854, 1034, 1303]
# ../data/HASC/HASC_TS_33.csv
# [1440 3006 4383 4862 6381]
# [1440, 3006, 4383, 4862, 6381, 7948]
# [1433, 3003, 4394, 4863, 6364, 7948]
# ../data/HASC/HASC_TS_36.csv
# [1542 3072 4590 6057 7485 8976]
# [1542, 3072, 4590, 6057, 7485, 8976, 10462]
# [893, 1523, 1763, 1973, 2234, 2403, 2623, 3053, 3923, 4583, 4783, 5094, 5313, 5433, 5623, 5734, 5953, 6513, 6663, 6814, 6983, 7463, 7933, 8963, 9413, 9514, 9863, 10024, 10164, 10462]
# ../data/HASC/HASC_TS_7.csv
# [1605 2846 4136 5300]
# [1605, 2846, 4136, 5300, 6375]
# [334, 1603, 2843, 3174, 4133, 4513, 5303, 5883, 6043, 6375]
# ../data/HASC/HASC_TS_87.csv
# [2227]
# [2227, 3561]
# [364, 573, 923, 1224, 2243, 2733, 2924, 3133, 3561]
# ../data/HASC/HASC_TS_88.csv
# [3309]
# [3309, 4446]
# [233, 734, 1113, 1363, 1683, 2824, 3253, 3333, 3663, 3923, 4446]
# ../data/HASC/HASC_TS_91.csv
# []
# [2761]
# [264, 684, 793, 1323, 2203, 2293, 2761]
# ../data/HASC/HASC_TS_95.csv
# []
# [456]
# [214, 456]
# ../data/HASC/HASC_TS_96.csv
# []
# [1137]
# [214, 564, 804, 1137]
# <wrappers.OrigRuLSIF object at 0x72c4acf6c9e0>
#                     0           1           2            3
# F1           0.624203    0.278045    0.166667     1.000000
# AUC          0.753835    0.161873    0.528571     1.000000
# FP           4.772727    5.597038    0.000000    24.000000
# DD         559.861032  864.257199    3.500000  4039.454545
# Threshold  100.000000    0.000000  100.000000   100.000000
# Covering     0.661647    0.256686    0.248657     0.995116
# Runtime      3.792443    2.486152    0.114990     9.543421
